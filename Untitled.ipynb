# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel('sales_data.xlsx')

# %%
df = df.iloc[3:]

# %%
df
# Out:
#       Unnamed: 0   Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 3            NaN     Retailer  Retailer ID         Invoice Date     Region
# 4            NaN  Foot Locker      1185732  2020-01-01 00:00:00  Northeast
# 5            NaN  Foot Locker      1185732  2020-01-02 00:00:00  Northeast
# 6            NaN  Foot Locker      1185732  2020-01-03 00:00:00  Northeast
# 7            NaN  Foot Locker      1185732  2020-01-04 00:00:00  Northeast
# ...          ...          ...          ...                  ...        ...
# 9647         NaN  Foot Locker      1185732  2021-01-24 00:00:00  Northeast
# 9648         NaN  Foot Locker      1185732  2021-01-24 00:00:00  Northeast
# 9649         NaN  Foot Locker      1185732  2021-02-22 00:00:00  Northeast
# 9650         NaN  Foot Locker      1185732  2021-02-22 00:00:00  Northeast
# 9651         NaN  Foot Locker      1185732  2021-02-22 00:00:00  Northeast
#
# ...

# %%
df.columns = df.iloc[0]
df = df[1:]

# %%
df.shape
# Out:
# (9648, 14)

# %%
df
# Out:
# 3     NaN     Retailer Retailer ID         Invoice Date     Region  \
# 4     NaN  Foot Locker     1185732  2020-01-01 00:00:00  Northeast
# 5     NaN  Foot Locker     1185732  2020-01-02 00:00:00  Northeast
# 6     NaN  Foot Locker     1185732  2020-01-03 00:00:00  Northeast
# 7     NaN  Foot Locker     1185732  2020-01-04 00:00:00  Northeast
# 8     NaN  Foot Locker     1185732  2020-01-05 00:00:00  Northeast
# ...   ...          ...         ...                  ...        ...
# 9647  NaN  Foot Locker     1185732  2021-01-24 00:00:00  Northeast
# 9648  NaN  Foot Locker     1185732  2021-01-24 00:00:00  Northeast
# 9649  NaN  Foot Locker     1185732  2021-02-22 00:00:00  Northeast
# 9650  NaN  Foot Locker     1185732  2021-02-22 00:00:00  Northeast
# 9651  NaN  Foot Locker     1185732  2021-02-22 00:00:00  Northeast
#
# 3             State        City                    Product Price per Unit  \
# 4          New York    New York      Men's Street Footwear             50
# ...

# %%
df.drop(df.columns[[0, 2]], axis=1, inplace=True)

df
# Out:
# C:\Users\2909k\AppData\Local\Temp\ipykernel_15516\1211943883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df.columns[[0, 2]], axis=1, inplace=True)
# 3        Retailer         Invoice Date     Region          State        City  \
# 4     Foot Locker  2020-01-01 00:00:00  Northeast       New York    New York
# 5     Foot Locker  2020-01-02 00:00:00  Northeast       New York    New York
# 6     Foot Locker  2020-01-03 00:00:00  Northeast       New York    New York
# 7     Foot Locker  2020-01-04 00:00:00  Northeast       New York    New York
# 8     Foot Locker  2020-01-05 00:00:00  Northeast       New York    New York
# ...           ...                  ...        ...            ...         ...
# 9647  Foot Locker  2021-01-24 00:00:00  Northeast  New Hampshire  Manchester
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 4 to 9651
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Invoice Date      9648 non-null   object
#  2   Region            9648 non-null   object
#  3   State             9648 non-null   object
#  4   City              9648 non-null   object
#  5   Product           9648 non-null   object
#  6   Price per Unit    9648 non-null   object
#  7   Units Sold        9648 non-null   object
#  8   Total Sales       9648 non-null   object
#  9   Operating Profit  9648 non-null   object
#  10  Operating Margin  9648 non-null   object
#  11  Sales Method      9648 non-null   object
# dtypes: object(12)
# memory usage: 904.6+ KB

# %%
df['Retailer'].isnull().sum()
# Out:
# 0

# %%
df['Retailer'].duplicated().sum()
# Out:
# 9642

# %%
df['State'].isnull().sum()
df['State'].duplicated().sum()
# Out:
# 9598

# %%
df['City'].duplicated().sum()
df['City'].isnull().sum()
# Out:
# 0

# %%
df['Product'].duplicated().sum()
df['Product'].isnull().sum()
# Out:
# 0

# %%
df['Price per Unit'].duplicated().sum()
df['Price per Unit'].isnull().sum()
# Out:
# 0

# %%
df['Units Sold'].duplicated().sum()
df['Units Sold'].isnull().sum()
# Out:
# 0

# %%
df['Total Sales'].duplicated().sum()
df['Total Sales'].isnull().sum()
# Out:
# 0

# %%
df['Operating Profit'].duplicated().sum()
df['Operating Profit'].isnull().sum()
# Out:
# 0

# %%
df['Operating Margin'].duplicated().sum()
df['Operating Margin'].isnull().sum()
# Out:
# 0

# %%
df['Sales Method'].duplicated().sum()
df['Sales Method'].isnull().sum()
# Out:
# 0

# %%
df['Retailer'].value_counts()
# Out:
# Retailer
# Foot Locker      2637
# West Gear        2374
# Sports Direct    2032
# Kohl's           1030
# Amazon            949
# Walmart           626
# Name: count, dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# Portland          360
# Charleston        288
# Orlando           216
# Salt Lake City    216
# Houston           216
# Boise             216
# Phoenix           216
# Albuquerque       216
# Atlanta           216
# New York          216
# Jackson           216
# Little Rock       216
# Oklahoma City     216
# Hartford          216
# Providence        216
# Boston            216
# Burlington        216
# Richmond          216
# New Orleans       216
# Manchester        216
# Dallas            216
# Philadelphia      216
# Knoxville         216
# Birmingham        216
# Las Vegas         216
# Los Angeles       216
# San Francisco     216
# Chicago           144
# Newark            144
# Baltimore         144
# Indianapolis      144
# Milwaukee         144
# Des Moines        144
# Fargo             144
# Sioux Falls       144
# Wichita           144
# Wilmington        144
# Honolulu          144
# Albany            144
# Louisville        144
# Columbus          144
# ...

# %%
df['State'].value_counts()
# Out:
# State
# California        432
# Texas             432
# New York          360
# Florida           360
# Mississippi       216
# Oregon            216
# Louisiana         216
# Idaho             216
# New Mexico        216
# Georgia           216
# Arkansas          216
# Virginia          216
# Oklahoma          216
# Connecticut       216
# Rhode Island      216
# Massachusetts     216
# Vermont           216
# Utah              216
# Arizona           216
# New Hampshire     216
# Pennsylvania      216
# Nevada            216
# Alabama           216
# Tennessee         216
# South Dakota      144
# Illinois          144
# Colorado          144
# New Jersey        144
# Delaware          144
# Maryland          144
# West Virginia     144
# Indiana           144
# Wisconsin         144
# Iowa              144
# North Dakota      144
# Michigan          144
# Kansas            144
# Missouri          144
# Minnesota         144
# Montana           144
# Kentucky          144
# ...

# %%
df['Product'].value_counts()
# Out:
# Product
# Men's Street Footwear        1610
# Men's Athletic Footwear      1610
# Women's Street Footwear      1608
# Women's Apparel              1608
# Women's Athletic Footwear    1606
# Men's Apparel                1606
# Name: count, dtype: int64

# %%
df['Sales Method'].value_counts()
# Out:
# Sales Method
# Online      4889
# Outlet      3019
# In-store    1740
# Name: count, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# Region
# West         2448
# Northeast    2376
# Midwest      1872
# South        1728
# Southeast    1224
# Name: count, dtype: int64

# %%
df['Total Sales'].sum()
# Out:
# 899902125.0

# %%
df['Operating Profit'].sum()
# Out:
# 332134761.44999886

# %% [markdown]
# # Data Visualization

# %%
sns.displot(df['Region'])

# %%
sns.displot(df['State'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.displot(df['Product'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.displot(df['Retailer'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.displot(df['Sales Method'])
plt.show()

# %%
sns.barplot(x = df['Sales Method'],y = df['Total Sales'])
# Out:
# <Axes: xlabel='Sales Method', ylabel='Total Sales'>

# %%
sns.barplot(x = df['Sales Method'],y = df['Operating Profit'])
# Out:
# <Axes: xlabel='Sales Method', ylabel='Operating Profit'>

# %%
sns.barplot(x = df['Retailer'],y = df['Total Sales'])
# Out:
# <Axes: xlabel='Retailer', ylabel='Total Sales'>

# %%
sns.barplot(x = df['Retailer'],y = df['Operating Profit'])
# Out:
# <Axes: xlabel='Retailer', ylabel='Operating Profit'>

# %%
sns.barplot(x = df['Region'],y = df['Total Sales'])
# Out:
# <Axes: xlabel='Region', ylabel='Total Sales'>

# %%
sns.barplot(x = df['Region'],y = df['Operating Profit'])
# Out:
# <Axes: xlabel='Region', ylabel='Operating Profit'>

# %%
sns.barplot(x = df['Product'],y = df['Total Sales'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.barplot(x = df['Product'],y = df['Operating Profit'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.barplot(x = df['State'],y = df['Total Sales'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.barplot(x = df['State'],y = df['Operating Profit'])
plt.xticks(rotation = 'vertical')
plt.show()
